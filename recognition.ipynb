# %%
pip install python_speech_features
# Out:
# Requirement already satisfied: python_speech_features in c:\users\jatin\appdata\local\programs\python\python311\lib\site-packages (0.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install moviepy # I installed this to just check mp4 to wav conversion, I have used the original Wav files provided
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#--------------------------------------Rishab Bairi---B21117-------------------------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc, logfbank

frequency_sampling, audio_signal = wavfile.read("Speaker_data/Voice_Samples_Training/Abhay-001/Abhay_1.wav")

# %%
frequency_sampling, audio_signal = wavfile.read("Speaker_data/Voice_Samples_Training/Abhay-001/Abhay_2.wav")
print(audio_signal.shape)
audio_signal =audio_signal[0:30000]
features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)

print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
print('Length of each feature =', features_mfcc.shape[1])



features_mfcc = features_mfcc.T
plt.matshow(features_mfcc)
plt.title('MFCC')
# Out:
# (250393, 2)
#
# MFCC:
# Number of windows = 135
# Length of each feature = 13
# Text(0.5, 1.0, 'MFCC')

# %%
print(audio_signal.shape)
# Out:
# (30000, 2)

# %%
print(type(features_mfcc))
# Out:
# <class 'numpy.ndarray'>

# %%
df = pd.DataFrame()
base_path = "Speaker_data/Voice_Samples_Training/Abhay-001/"
j = 0 
m = 0  

print("Training phase")

# ---------- Speaker 1: Abhay ----------
for i in range(1, 6): 
    filename = f"Abhay_{i}.wav"
    full_path = base_path + filename
    
    frequency_sampling, audio_signal = wavfile.read(full_path)
    features_mfcc = mfcc(audio_signal, frequency_sampling, nfft=1103) 
    
    if j == 0: 
        df = pd.DataFrame(features_mfcc)
        df['Class'] = m
        j += 1
    else: 
        jd = pd.DataFrame(features_mfcc)
        jd['Class'] = m
        df = pd.concat([df, jd], ignore_index=True)

    print(type(features_mfcc))
    print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
    print('Length of each feature =', features_mfcc.shape[1])
    features_mfcc = features_mfcc.T 

m += 1 

# ---------- Speaker 2: Eknath ----------
base_path = "Speaker_data/Voice_Samples_Training/Eknath-002/"
for i in range(1, 6):
    filename = f"Eknath_{i}.wav"
    full_path = base_path + filename
    
    frequency_sampling, audio_signal = wavfile.read(full_path)
    features_mfcc = mfcc(audio_signal, frequency_sampling, nfft=1103) 
    
    if j == 0: 
        df = pd.DataFrame(features_mfcc)
        df['Class'] = m
        j += 1
    else: 
        jd = pd.DataFrame(features_mfcc)
        jd['Class'] = m
        df = pd.concat([df, jd], ignore_index=True)  # ✅ FIXED LINE

    print(type(features_mfcc))
    print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
    print('Length of each feature =', features_mfcc.shape[1])
    features_mfcc = features_mfcc.T 

print(df)
# Out:
# Training phase
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1067
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1135
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1047
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1151
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1039
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1119
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1195
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1203
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1171
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1391
# Length of each feature = 13
#                0          1          2          3          4          5  \
# 0       3.709153 -17.892319 -22.465258 -10.380653 -18.928595  -8.633639
# 1       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 2     -36.043653   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 4       1.356769 -22.244437 -29.294535  -5.948628  -4.746628 -15.319954
# ...          ...        ...        ...        ...        ...        ...
# 11513   9.133110  20.316716   0.509342  -9.988112  19.157022  20.340710
# 11514   9.484080  22.157122   1.783169  -8.122282  21.277034  14.030394
# 11515   9.630948  21.603672   0.867688  -7.392343  23.807197  15.575161
# 11516   9.778191  21.254534   2.545940  -4.197126  22.123908  15.322952
# 11517   9.100815  22.005790   3.056249  -7.921473  21.262357  18.820914
#
#                   6          7          8         9            10         11  \
# 0     -2.667630e+01 -15.432049  -9.530002  5.684299  3.618394e+00  11.867610
# 1      2.826322e+00  -7.380674  -6.516295  7.168687 -1.569765e+01  11.728846
# 2     -3.432169e-14   0.000000   0.000000  0.000000  9.640287e-15   0.000000
# 3      2.826322e+00  -7.380674  -6.516295  7.168687 -1.569765e+01  11.728846
# 4      2.928440e+00  -7.226422  -6.272190  7.512139 -1.528681e+01  12.151631
# ...             ...        ...        ...       ...           ...        ...
# 11513  9.472123e-01  -1.420128  23.703038  0.344517  1.297403e+01   4.729930
# 11514  2.026241e+00  -0.230737  22.543704 -3.177108  4.821016e+00   5.451557
# 11515  4.935526e+00   5.490200  26.469635 -4.232686  7.494036e+00   5.658920
# 11516  2.149163e+00   2.098299  24.286833  0.577203  1.108668e+01   4.401706
# 11517 -4.596723e-01  -3.080553  29.467344  6.397017  1.288950e+01   9.345330
#
#               12  Class
# 0       6.356574      0
# 1     -12.426778      0
# 2       0.000000      0
# 3     -12.426778      0
# 4     -12.044024      0
# ...          ...    ...
# 11513  11.648393      1
# 11514  10.719789      1
# 11515  10.986555      1
# 11516  11.511439      1
# 11517  14.927327      1
#
# [11518 rows x 14 columns]

# %%
m = m + 1 
base_path = "Speaker_data/Voice_Samples_Training/Rg-003/"
for i in range(1, 6):  
    filename = f"Rg_{i}.wav"
    full_path = base_path + filename
    
    frequency_sampling, audio_signal = wavfile.read(full_path)
    features_mfcc = mfcc(audio_signal, frequency_sampling, nfft=1103) 
    if j == 0: 
        df = pd.DataFrame(features_mfcc)
        df['Class'] = m
        j += 1
    else: 
        jd = pd.DataFrame(features_mfcc)
        jd['Class'] = m
        df = pd.concat([df, jd], ignore_index=True)  # ✅ fixed
    print(type(features_mfcc))
    print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
    print('Length of each feature =', features_mfcc.shape[1])
    features_mfcc = features_mfcc.T 

print(df)

m = m + 1 
base_path = "Speaker_data/Voice_Samples_Training/Rishika-004/"
for i in range(1, 6):  
    filename = f"Rishika_{i}.wav"
    full_path = base_path + filename
    
    frequency_sampling, audio_signal = wavfile.read(full_path)
    features_mfcc = mfcc(audio_signal, frequency_sampling, nfft=1103) 
    if j == 0: 
        df = pd.DataFrame(features_mfcc)
        df['Class'] = m
        j += 1
    else: 
        jd = pd.DataFrame(features_mfcc)
        jd['Class'] = m
        df = pd.concat([df, jd], ignore_index=True)  # ✅ fixed
    print(type(features_mfcc))
    print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
    print('Length of each feature =', features_mfcc.shape[1])
    features_mfcc = features_mfcc.T 

print(df)

m = m + 1 
base_path = "Speaker_data/Voice_Samples_Training/Vaibhav-005/"
for i in range(1, 6):  
    filename = f"Vaibhav_{i}.wav"
    full_path = base_path + filename

    frequency_sampling, audio_signal = wavfile.read(full_path) 
    audio_signal = audio_signal[0:int(len(audio_signal)/5)]
    features_mfcc = mfcc(audio_signal, frequency_sampling, nfft=1103) 
    if j == 0: 
        df = pd.DataFrame(features_mfcc)
        df['Class'] = m
        j += 1
    else: 
        jd = pd.DataFrame(features_mfcc)
        jd['Class'] = m
        df = pd.concat([df, jd], ignore_index=True)  # ✅ fixed
    print(type(features_mfcc))
    print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
    print('Length of each feature =', features_mfcc.shape[1])
    features_mfcc = features_mfcc.T 

print(df)

m = m + 1 
base_path = "Speaker_data/Voice_Samples_Training/ShivamY-006/"
for i in range(1, 6):  
    filename = f"chappu_{i}.wav"
    full_path = base_path + filename

    frequency_sampling, audio_signal = wavfile.read(full_path)
    audio_signal = audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling, nfft=1103) 
    if j == 0: 
        df = pd.DataFrame(features_mfcc)
        df['Class'] = m
        j += 1
    else: 
        jd = pd.DataFrame(features_mfcc)
        jd['Class'] = m
        df = pd.concat([df, jd], ignore_index=True)  # ✅ fixed
    print(type(features_mfcc))
    print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
    print('Length of each feature =', features_mfcc.shape[1])
    features_mfcc = features_mfcc.T 

print(df)
# Out:
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 995
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1119
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 975
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1047
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 963
# Length of each feature = 13
#                0          1          2          3          4          5  \
# 0       3.709153 -17.892319 -22.465258 -10.380653 -18.928595  -8.633639
# 1       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 2     -36.043653   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 4       1.356769 -22.244437 -29.294535  -5.948628  -4.746628 -15.319954
# ...          ...        ...        ...        ...        ...        ...
# 16612  13.667839  36.182175   7.378857 -14.624095  32.181659  -2.830463
# 16613  13.240359  32.737287   7.153838 -10.259678  27.523294  -0.096855
# 16614  12.887192  30.079192   6.637610  -7.690955  21.125259   3.329369
# 16615  12.437850  32.187224   5.732442 -11.724766  29.170861   0.138223
# 16616  11.744776  25.940716   8.006093   0.906471  16.065766  -2.821664
#
#                   6          7          8          9            10         11  \
# 0     -2.667630e+01 -15.432049  -9.530002   5.684299  3.618394e+00  11.867610
# 1      2.826322e+00  -7.380674  -6.516295   7.168687 -1.569765e+01  11.728846
# 2     -3.432169e-14   0.000000   0.000000   0.000000  9.640287e-15   0.000000
# 3      2.826322e+00  -7.380674  -6.516295   7.168687 -1.569765e+01  11.728846
# 4      2.928440e+00  -7.226422  -6.272190   7.512139 -1.528681e+01  12.151631
# ...             ...        ...        ...        ...           ...        ...
# 16612  1.045178e+01  21.341587  49.636638 -14.467534  1.231833e+01  13.808493
# 16613  6.196472e+00  15.070322  38.006709  -9.865036  1.262008e+01  15.830139
# 16614  6.340131e+00  10.367353  34.527189  -0.103348  1.239666e+01  12.782670
# 16615  2.902141e+00  12.435485  43.844930  -3.664445  1.476649e+01   9.037320
# 16616  2.959378e+00  10.865809  28.915110   2.789478  3.279497e+00   3.012785
#
#               12  Class
# 0       6.356574      0
# 1     -12.426778      0
# 2       0.000000      0
# 3     -12.426778      0
# 4     -12.044024      0
# ...          ...    ...
# 16612   7.147870      3
# 16613  15.136286      3
# 16614  14.629765      3
# 16615   7.528741      3
# 16616   1.940440      3
#
# [16617 rows x 14 columns]
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1187
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1267
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1251
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1143
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 1231
# Length of each feature = 13
#                0          1          2          3          4          5  \
# 0       3.709153 -17.892319 -22.465258 -10.380653 -18.928595  -8.633639
# 1       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 2     -36.043653   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 4       1.356769 -22.244437 -29.294535  -5.948628  -4.746628 -15.319954
# ...          ...        ...        ...        ...        ...        ...
# 22691   6.396212   6.265619  -7.185081 -11.331311  -7.202466   6.867961
# 22692   6.175020   7.314687  -5.104795  -9.028174  -9.023881   2.740205
# 22693   6.634113   8.689286  -3.484911  -9.125177 -11.523925  -0.622548
# 22694   6.822525   8.841342  -3.105281  -7.967794 -11.572532  -2.298551
# 22695   6.488341  10.256832  -1.168172  -6.109170  -8.983117  -1.438278
#
#                   6          7          8          9            10         11  \
# 0     -2.667630e+01 -15.432049  -9.530002   5.684299  3.618394e+00  11.867610
# 1      2.826322e+00  -7.380674  -6.516295   7.168687 -1.569765e+01  11.728846
# 2     -3.432169e-14   0.000000   0.000000   0.000000  9.640287e-15   0.000000
# 3      2.826322e+00  -7.380674  -6.516295   7.168687 -1.569765e+01  11.728846
# 4      2.928440e+00  -7.226422  -6.272190   7.512139 -1.528681e+01  12.151631
# ...             ...        ...        ...        ...           ...        ...
# 22691 -8.919548e+00  -1.027641  16.423062  14.983091  1.153222e+01   0.788111
# 22692 -1.185521e+01  -4.230129   6.724911   5.935389  2.885238e+00  -3.496896
# 22693 -1.472851e+01  -5.250927   6.531502   0.379347 -1.290814e+00  -3.298823
# 22694 -1.563343e+01  -6.357434   7.145167   3.188402 -2.300255e+00  -0.161252
# 22695 -1.413979e+01  -3.536149  11.364780   7.611502  3.779618e+00   4.869383
#
#               12  Class
# 0       6.356574      0
# 1     -12.426778      0
# 2       0.000000      0
# 3     -12.426778      0
# 4     -12.044024      0
# ...          ...    ...
# 22691   0.780328      4
# 22692   1.898927      4
# 22693   4.607371      4
# 22694   3.336328      4
# 22695   5.974302      4
#
# [22696 rows x 14 columns]
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 251
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 211
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 258
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 235
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 308
# Length of each feature = 13
#                0          1          2          3          4          5  \
# 0       3.709153 -17.892319 -22.465258 -10.380653 -18.928595  -8.633639
# 1       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 2     -36.043653   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 4       1.356769 -22.244437 -29.294535  -5.948628  -4.746628 -15.319954
# ...          ...        ...        ...        ...        ...        ...
# 23954  16.581725  42.359079  11.658628 -14.359489  27.013581  11.199465
# 23955  16.555039  33.279896  11.484098  -4.866699  13.121337  10.657051
# 23956  16.862354  41.892097  13.486024 -11.380754  25.855296   7.713821
# 23957  16.772600  38.153908  13.982666 -10.453135  14.463064   6.434721
# 23958  16.669487  32.243711  11.840896  -4.316694  12.084298  12.494809
#
#                   6          7          8         9            10         11  \
# 0     -2.667630e+01 -15.432049  -9.530002  5.684299  3.618394e+00  11.867610
# 1      2.826322e+00  -7.380674  -6.516295  7.168687 -1.569765e+01  11.728846
# 2     -3.432169e-14   0.000000   0.000000  0.000000  9.640287e-15   0.000000
# 3      2.826322e+00  -7.380674  -6.516295  7.168687 -1.569765e+01  11.728846
# 4      2.928440e+00  -7.226422  -6.272190  7.512139 -1.528681e+01  12.151631
# ...             ...        ...        ...       ...           ...        ...
# 23954  2.342677e+01   8.355671  34.892004 -6.576226  9.283770e+00  -8.134475
# 23955  2.203044e+01   9.382855  20.393691 -0.617968  5.239864e+00  -7.296185
# 23956  2.333377e+01   7.911435  31.347639 -4.639892  9.652259e+00  -7.981435
# 23957  2.002537e+01   6.693314  26.865105 -0.236137  8.859954e+00  -5.251418
# 23958  2.306393e+01  12.207787  21.442510 -0.371901  9.993776e-01  -9.643241
#
#               12  Class
# 0       6.356574      0
# 1     -12.426778      0
# 2       0.000000      0
# 3     -12.426778      0
# 4     -12.044024      0
# ...          ...    ...
# 23954   7.730038      5
# 23955   5.756162      5
# 23956   5.340731      5
# 23957   7.322645      5
# 23958   3.275173      5
#
# [23959 rows x 14 columns]
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 135
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 135
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 135
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 135
# Length of each feature = 13
# <class 'numpy.ndarray'>
#
# MFCC:
# Number of windows = 135
# Length of each feature = 13
#                0          1          2          3          4          5  \
# 0       3.709153 -17.892319 -22.465258 -10.380653 -18.928595  -8.633639
# 1       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 2     -36.043653   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.663619 -22.264553 -29.325811  -5.991876  -4.802390 -15.387926
# 4       1.356769 -22.244437 -29.294535  -5.948628  -4.746628 -15.319954
# ...          ...        ...        ...        ...        ...        ...
# 24629  12.929451  32.956260   2.227463 -16.369231  35.306553   0.646987
# 24630  12.254072  35.116208   0.276707 -25.891480  34.219510  -2.490966
# 24631  11.871612  29.224394   0.037754 -16.475882  21.923250  -3.658891
# 24632  11.688967  30.503205  -1.124850 -22.483073  18.846096 -10.041426
# 24633  11.631151  25.512456   0.151374 -15.032082   9.656098  -6.178590
#
#                   6          7          8          9            10         11  \
# 0     -2.667630e+01 -15.432049  -9.530002   5.684299  3.618394e+00  11.867610
# 1      2.826322e+00  -7.380674  -6.516295   7.168687 -1.569765e+01  11.728846
# 2     -3.432169e-14   0.000000   0.000000   0.000000  9.640287e-15   0.000000
# 3      2.826322e+00  -7.380674  -6.516295   7.168687 -1.569765e+01  11.728846
# 4      2.928440e+00  -7.226422  -6.272190   7.512139 -1.528681e+01  12.151631
# ...             ...        ...        ...        ...           ...        ...
# 24629  9.758020e+00  -1.660670  16.412254 -22.852912  1.036391e+01  10.247416
# 24630  8.094726e+00   1.140221  24.818679 -32.849507  1.891518e+01  16.875140
# 24631  4.974307e+00  -4.434552  15.603126 -20.506756  9.461362e+00  10.804835
# 24632 -4.486194e+00 -16.528671  10.762080 -22.092497  3.218479e+00   0.532307
# 24633 -2.832059e+00 -11.525360   8.266911 -12.067970  2.934119e+00   3.991115
#
#               12  Class
# 0       6.356574      0
# 1     -12.426778      0
# 2       0.000000      0
# 3     -12.426778      0
# 4     -12.044024      0
# ...          ...    ...
# 24629  13.133173      6
# 24630  14.376689      6
# 24631  12.303288      6
# 24632  11.586225      6
# 24633  11.792301      6
#
# [24634 rows x 14 columns]

# %%
from sklearn.mixture import GaussianMixture

# Filter data for each speaker
Abhay   = df[df['Class'] == 0]
Eknath  = df[df['Class'] == 1]
Rg      = df[df['Class'] == 2]
Rishika = df[df['Class'] == 3]
Vaibhav = df[df['Class'] == 4]
Shivam  = df[df['Class'] == 5]

# Create GMMs only for non-empty classes
gmmlis = {}

for i, speaker_df in enumerate([Abhay, Eknath, Rg, Rishika, Vaibhav, Shivam]):
    if len(speaker_df) >= 2:
        gmm = GaussianMixture(n_components=2, random_state=5)
        gmm.fit(speaker_df.iloc[:, :13])  # Fit only MFCC features
        gmmlis[i] = gmm
        print(f"✅ GMM trained for speaker class {i} with {len(speaker_df)} samples.")
    else:
        print(f"❌ Skipped speaker class {i} — only {len(speaker_df)} sample(s).")
# Out:
# ✅ GMM trained for speaker class 0 with 5439 samples.
# ✅ GMM trained for speaker class 1 with 6079 samples.
# ❌ Skipped speaker class 2 — only 0 sample(s).
# ✅ GMM trained for speaker class 3 with 5099 samples.
# ✅ GMM trained for speaker class 4 with 6079 samples.
# ✅ GMM trained for speaker class 5 with 1263 samples.

# %%
import statistics
from statistics import mode 
import warnings 
warnings.filterwarnings("ignore", category=UserWarning)

speakers = ["Abhay", "Eknath","Rg","Rishika","Vaibhav","ShivamY"]
def classify_test_data(models, test_features):
    predictions = []

    for i in range(len(test_features)): 
        lis = test_features.iloc[i,:]
        max_score = -float('inf')
        predicted_speaker = None
        
        for speaker, model in models.items(): 
           
            score = model.score([lis])
            if score > max_score:
                max_score = score
                predicted_speaker = speaker

        predictions.append(predicted_speaker)

    return predictions 
actual={}
base_path = "Speaker_data/Testing_Audio/" 
k = 0
m=0
correct_coun = 0
for i in range(1, 6):  
    filename = f"Abhay_audio{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T)  
    k = k+1 
    if(mode(predictions)==m):
        correct_coun = correct_coun+1
    print(filename+"-"+speakers[mode(predictions)]) 
print("\n")
m=m+1
base_path = "Speaker_data/Testing_Audio/"
for i in range(1, 6):  
    filename = f"Eknath_audio{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T) 
    k = k+1
    if(mode(predictions)==m):
        correct_coun = correct_coun+1
    print(filename+"-"+speakers[mode(predictions)]) 
print("\n")
m=m+1
base_path = "Speaker_data/Testing_Audio/"
for i in range(1, 6):
    filename = f"Rg_audio{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T) 
    k = k+1
    if(mode(predictions)==m):
        correct_coun = correct_coun+1
    print(filename+"-"+speakers[mode(predictions)])
print("\n")
m=m+1
base_path = "Speaker_data/Testing_Audio/"
for i in range(1, 6):  
    filename = f"Rishika_audio{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T) 
    k = k+1
    if(mode(predictions)==m):
        correct_coun = correct_coun+1
    print(filename+"-"+speakers[mode(predictions)])
print("\n")
m=m+1
base_path = "Speaker_data/Testing_Audio/"
for i in range(1, 6):  
    filename = f"Vaibhav_audio{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T) 
    k = k+1
    if(mode(predictions)==m):
        correct_coun = correct_coun+1
    print(filename+"-"+speakers[mode(predictions)])
print("\n")
m=m+1    
base_path = "Speaker_data/Testing_Audio/"
for i in range(1, 6): 
    filename = f"ShivamY_audio{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T) 
    k = k+1
    if(mode(predictions)==m):
        correct_coun = correct_coun+1
    print(filename+"-"+speakers[mode(predictions)])
print("\n")
print("\n")
base_path = "Speaker_data/Testing_Audio/"
for i in range(1, 7):  
    filename = f"P{i}.wav"
    full_path = base_path + filename
    frequency_sampling, audio_signal = wavfile.read(full_path)
    #audio_signal =audio_signal[0:30000]
    features_mfcc = mfcc(audio_signal, frequency_sampling,nfft=1103)
    df = pd.DataFrame(features_mfcc.T)
    predictions = classify_test_data(gmmlis, df.T) 
    print(filename+"-"+speakers[mode(predictions)])
print("\n")
print("Accuracy is :",(correct_coun/k*100))
# Out:
# Abhay_audio1.wav-Abhay
# Abhay_audio2.wav-Abhay
# Abhay_audio3.wav-Abhay
# Abhay_audio4.wav-Abhay
# Abhay_audio5.wav-Eknath
#
#
# Eknath_audio1.wav-Eknath
# Eknath_audio2.wav-Eknath
# Eknath_audio3.wav-Eknath
# Eknath_audio4.wav-Eknath
# Eknath_audio5.wav-Eknath
#
#
# Rg_audio1.wav-Rishika
# Rg_audio2.wav-Rishika
# Rg_audio3.wav-Rishika
# Rg_audio4.wav-Rishika
# Rg_audio5.wav-Rishika
#
#
# Rishika_audio1.wav-Vaibhav
# Rishika_audio2.wav-Vaibhav
# Rishika_audio3.wav-Vaibhav
# Rishika_audio4.wav-Vaibhav
# Rishika_audio5.wav-Vaibhav
#
#
# Vaibhav_audio1.wav-ShivamY
# Vaibhav_audio2.wav-ShivamY
# Vaibhav_audio3.wav-ShivamY
# Vaibhav_audio4.wav-ShivamY
# Vaibhav_audio5.wav-ShivamY
#
#
# ShivamY_audio1.wav-Eknath
# ShivamY_audio2.wav-Eknath
# ShivamY_audio3.wav-Eknath
# ShivamY_audio4.wav-Abhay
# ShivamY_audio5.wav-Eknath
#
#
#
#
# P1.wav-Abhay
# P2.wav-Eknath
# P3.wav-Rishika
# P4.wav-Vaibhav
# P5.wav-Eknath
# P6.wav-ShivamY
#
#
# Accuracy is : 30.0
